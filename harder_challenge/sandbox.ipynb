# %%
import os
import pandas as pd

# %%
os.listdir()
# Out:
# ['Atlanta_supply_dat.xlsx - Atlanta_dat.csv',
#  'Atlanta_supply_dat.xlsx - UC_buildings.csv',
#  'challenge_details.pdf',
#  'sandbox.ipynb']

# %%
dat = pd.read_csv("Atlanta_supply_dat.xlsx - Atlanta_dat.csv")
bui = pd.read_csv("Atlanta_supply_dat.xlsx - UC_buildings.csv")

# %%
dat
# Out:
#    MarketCode MarketName  YearQuarter  Stock_sf  Completions_sf  \
# 0      ATLANT    Atlanta       2000.1    397465            4394
# 1      ATLANT    Atlanta       2000.2    401081            3616
# 2      ATLANT    Atlanta       2000.3    405850            4769
# 3      ATLANT    Atlanta       2000.4    412672            6822
# 4      ATLANT    Atlanta       2001.1    416867            4195
# ..        ...        ...          ...       ...             ...
# 91     ATLANT    Atlanta       2022.4    696700            9045
# 92     ATLANT    Atlanta       2023.1    703240            6540
# 93     ATLANT    Atlanta       2023.2    708037            4797
# 94     ATLANT    Atlanta       2023.3    717677            9640
# 95     ATLANT    Atlanta       2023.4    730346           12669
#
#     Stock_Under_Construction_sf  under_construction_as_a_percentage_of_Stock
# 0                          4098                                        1.031
# ...

# %%
bui
# Out:
#      PropertyID  VendorID                                            Address  \
# 0    1652916003         2                  5640 Eden Rd  Kennedale, TX 76060
# 1    1652901399         2           1801 N Masch Branch Rd  Denton, TX 76207
# 2    1652907044         2             765 E GA 16 Highway   Newnan, GA 30263
# 3    1652887791         2              121 Technology Park   Allen, TX 75013
# 4    1652900810         2              2733 Basswood Blvd  Saginaw, TX 76131
# ..          ...       ...                                                ...
# 216  1652897664         2                          ICC-35   Denton, TX 76207
# 217  1652887966         2                   1400 Senoia Rd  Tyrone, GA 30290
# 218  1652915198         2       TX SH 180 & Boswell Dr  Fort Worth, TX 76112
# 219  1652926524         2  SEC Loop of 820 & N Beach   Haltom City, TX 76137
# 220  1652864940         2                     HWY 287   Waxahachie, TX 75165
#
# ...
